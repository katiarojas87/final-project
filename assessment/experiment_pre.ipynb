# %%
from final_project_package.ml_logic.data_clean import initialize_clip
from sklearn.metrics import log_loss, accuracy_score, precision_score, recall_score
# %store -r df_cleaned

# %%
df_cleaned.head()
# Out:
#    source_id     RoomType Luxury Brightness Condition  \
# 0   20277732  living room    yes        yes       new
# 2   20277732  living room    yes        yes       new
# 3   20277732      kitchen    yes        yes       new
# 4   20277732      bedroom     no        yes       old
# 5   20277732     bathroom    yes        yes       new
#
#                                           image_path room_type  \
# 0  raw_data/suumo_images/20277732/20277732_eaa711...   kitchen
# 2  raw_data/suumo_images/20277732/20277732_274be4...  bathroom
# 3  raw_data/suumo_images/20277732/20277732_c35b74...   kitchen
# 4  raw_data/suumo_images/20277732/20277732_bbd7ff...  bathroom
# 5  raw_data/suumo_images/20277732/20277732_8b8db6...  bathroom
#
#                                         scoring_dict  score_lux  score_bright  \
# 0  {'luxury': 0.37890625, 'brightness': 0.2695312...   0.378906      0.269531
# 2  {'luxury': 0.37890625, 'brightness': 0.2226562...   0.378906      0.222656
# ...

# %%
#Label templates
attributes_list = ["brigthness", "luxury", "modern"]

for attribute in attributes_list:

    def build_labels(room_type, attribute):
        templates = {
            "luxury": [
                f"a photo of a expensive, luxurious {room_type} with premium finishes",
                f"a photo of a cheap, basic {room_type} with low-quality materials",
            ],
            "brightness": [
                f"a bright, well-lit {room_type} with natural light",
                f"a dark, poorly lit {room_type}",
            ],
            "condition": [
                f"a photo of a brand new, renovated {room_type}",
                f"a photo of an old, worn-out {room_type} in poor condition",
            ]
        }
        return templates[attribute]

# %%
#scoring
def get_score(image_path, templates[attribute], clip):


return clip(image_path, candidate_labels=labels)

# %%
def get_accuracy (log_loss, accuracy_score, precision, recall):

    loss_lux = log_loss(df_cleaned["Luxury"] == "yes", df_cleaned["score_lux"])
    loss_bright = log_loss(df_cleaned["Brightness"] == "yes", df_cleaned["score_bright"])
    loss_cond = log_loss(df_cleaned["Condition"] == "new", df_cleaned["score_cond"])
    loss_lux, loss_bright, loss_cond

    cond_pred = df_cleaned["score_cond"] > 0.5
    cond_actual = df_cleaned["Condition"] == "new"
    accuracy = accuracy_score(cond_pred, cond_actual)
    accuracy

    return (log_loss, accuracy_score, precision, recall)
)

# %%
def run_experiment(
  df_cleaned,
  attribute = "brightness",
  clip_labels = ["a bright room", "a dark room"]
):

  log_loss = 0.0; #???
  accuracy_score = 0.0; #???
  precision = 0.0; # ???
  recall = 0.0; # ???

  return (log_loss, accuracy_score, precision, recall);
