# %%
import pandas as pd
import pathlib

# Sklearn preprocessing
from sklearn.feature_selection import SelectPercentile, mutual_info_regression, VarianceThreshold, SelectFromModel
from sklearn.impute import SimpleImputer, KNNImputer


from sklearn.linear_model import LinearRegression, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV, cross_validate
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# Get the path of the current folder
data_path = pathlib.Path.cwd() / "raw_data"

# import images.csv
df = pd.read_csv(data_path / "listings_scores.csv")

X = df.drop(columns=["Price"]).copy()
y = df["Price"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 data_path = pathlib.Path.cwd() / "raw_data"
#       4 # import images.csv
# ----> 5 df = pd.read_csv(data_path / "listings_scores.csv")
#       7 X = df.drop(columns=["Price"]).copy()
#       8 y = df["Price"]
#
# ...

# %%
# scale numeric features with robust scaler
numeric_features = X.columns[X.dtypes!="object"]
numeric_transformer = Pipeline([
    ("SimpleImputer", SimpleImputer(strategy="mean")),
    ("scaler", MinMaxScaler())
])

# use a one-hot encoding for categorical features
categorical_features = X.columns[X.dtypes=="object"]
categorical_transformer = Pipeline([
    ("SimpleImputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(drop='if_binary', handle_unknown="ignore"))
])

# group all the transformers together into a single pipeline
preproc_baseline = ColumnTransformer(
  transformers=[
    ("numeric_xform", numeric_transformer, numeric_features),
    ("encoder_xform", categorical_transformer, categorical_features)
  ]
)

df_preproc = pd.DataFrame(preproc_baseline.fit_transform(X), columns=preproc_baseline.get_feature_names_out())
df_preproc.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # scale numeric features with robust scaler
# ----> 2 numeric_features = X.columns[X.dtypes!="object"]
#       3 numeric_transformer = Pipeline([
#       4     ("SimpleImputer", SimpleImputer(strategy="mean")),
#       5     ("scaler", MinMaxScaler())
#       6 ])
#       8 # use a one-hot encoding for categorical features
#
# NameError: name 'X' is not defined

# %%
model = LinearRegression()

pipe_baseline = Pipeline([
  ("preprocessor", preproc_baseline),
  ("linear_model", model)
])

pipe_baseline
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 model = LinearRegression()
#       3 pipe_baseline = Pipeline([
# ----> 4   ("preprocessor", preproc_baseline),
#       5   ("linear_model", model)
#       6 ])
#       8 pipe_baseline
#
# NameError: name 'preproc_baseline' is not defined
