# %%
#core
# !pip install scikit-learn --break-system-packages -q
import pandas as pd
import pathlib

#pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# Imputers
from sklearn.impute import SimpleImputer

# Numerical scalers
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import PowerTransformer

# Categorical encoders
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import TargetEncoder

# Model selection
from sklearn.model_selection import train_test_split, cross_val_score

# %%
#load dataset(double check name of the main dataframe)
data_path = pathlib.Path(".")
data = pd.read_csv(data_path / "raw_data/listings_with_scores.csv")
data.head()

#define features X and target
X = data.drop(columns=["price_man_yen"]).copy()
y = data["price_man_yen"]
# Out:
#    source_id                                                url  \
# 0   20143760  https://suumo.jp/ms/chuko/chiba/sc_ichikawa/nc...
# 1   20143796  https://suumo.jp/ms/chuko/chiba/sc_ichikawa/nc...
# 2   20071087  https://suumo.jp/ms/chuko/tokyo/sc_adachi/nc_2...
# 3   20101205  https://suumo.jp/ms/chuko/tokyo/sc_adachi/nc_2...
# 4   20277732  https://suumo.jp/ms/chuko/tokyo/sc_adachi/nc_2...
#
#    price_man_yen layout  area_sqm  year_built  floor_number  floors_total  \
# 0         5280.0   4LDK     77.31        2000           3.0           5.0
# 1         3799.0   3LDK     66.00        2000           3.0           6.0
# 2         2180.0   2LDK     60.33        1988           5.0          14.0
# 3         1480.0     1K     32.72        1988           4.0           4.0
# 4         2390.0   2LDK     52.89        1989           4.0           4.0
#
#                 address nearest_station  walk_minutes  image_count
# 0  千葉県市川市新井３ [ ■ 周辺環境 ]            南行徳駅           7.0            1
# 1  千葉県市川市広尾１ [ ■ 周辺環境 ]            南行徳駅          17.0            1
# 2  東京都足立区辰沼２ [ ■ 周辺環境 ]             NaN           NaN           24
# 3  東京都足立区栗原２ [ ■ 周辺環境 ]            西新井駅          10.0           10
# 4  東京都足立区六月１ [ ■ 周辺環境 ]            竹ノ塚駅          16.0           24

# %%
# train test split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

#(f"X_train\t{X_train.shape}", f"X_test\t{X_test.shape}", f"y_train\t{y_train.shape}", f"y_test\t{y_test.shape}")

# %%
num_transformer = Pipeline ([
    ("imputer", SimpleImputer(strategy="mean")), #Missing values, normally distributed
    ("standard_scaler", StandardScaler()), #Features on different scales, linear models
    ("minmax_scaler", MinMaxScaler()), #When you need values between 0–1
    ("robust_scaler", RobustScaler()) #Data with lots of outliers
])
cat_transformer = Pipeline ([
    ("ohe", OneHotEncoder(drop = "if_binary",handle_unknown="ignore")), #Nominal data (no order) e.g. region, room_type
    ("ordinal_encoder", OrdinalEncoder()), #Ordered categories e.g. small < medium < large
    ("imputer", SimpleImputer(strategy="most_frequent")) #Missing categorical values
])

# Preprocessing "num_transformer" and "cat_transfomer"
preprocessor = ColumnTransformer([
    ('num_transformer', num_transformer, ['column1', 'column2']),
    ('cat_transformer', cat_transformer, ['column1', 'column2'])
])

# %%
#checks preprocessed data
from IPython.display import display

#X_train_transformed = preprocessor.fit_transform(X_train)

print("Original training set")
#display(X_train.head(3))

print("Preprocessed training set")
#display(pd.DataFrame(X_train_transformed).head(3))
# Out:
# Original training set
# Preprocessed training set

# %%
#checks the preprocessor diagram
from sklearn import set_config
set_config(display="diagram")

preprocessor

# %%
#fitting preprocessor
#X_transformed = preprocessor.fit_transform(X)
#X_transformed

# %%
model = LinearRegression()

pipe_baseline = Pipeline([
  ("preprocessor", preproc_baseline),
  ("linear_model", model)
])

pipe_baseline

# %%
# Train Pipeline
#pipeline.fit(X_train,y_train)

# Make predictions
#print(X_test.iloc[0:1])
#print(pipeline.predict(X_test.iloc[0:1]))

# Score model
#pipeline.score(X_test,y_test)

# %%
preprocessor.get_feature_names_out()

# %%
pd.DataFrame(
    X_train_transformed,
    columns=preprocessor.get_feature_names_out()
).head()
